# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("C:\\Dump\\Ishwar\\Data_Science\\Edureka\\Class 10\\DataSets\\driver-data.csv")

# %%
df.head()
# Out:
#            id  mean_dist_day  mean_over_speed_perc
# 0  3423311935          71.24                    28
# 1  3423313212          52.53                    25
# 2  3423313724          64.54                    27
# 3  3423311373          55.69                    22
# 4  3423310999          54.58                    25

# %%
sns.scatterplot(df["mean_dist_day"],df["mean_over_speed_perc"])

# %%
sns.scatterplot(df["mean_over_speed_perc"],df["mean_dist_day"])

# %%
x=df.iloc[:,[1,2]]

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init="k-means++")
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [12184626.129627975,
#  1316420.8509477186,
#  992634.060670247,
#  719601.1096991899,
#  534667.5520616842,
#  372836.03596936155,
#  319728.7000606831,
#  276909.8561266839,
#  252669.50380767643,
#  230001.18334137992]

# %%
plt.plot(range(1,11),wcss)

# %%
kmeans=KMeans(n_clusters=2, init="k-means++")
y_kmeans=kmeans.fit_predict(x)

# %%
y_kmeans
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
x["clusters"]=y_kmeans

# %%
y_kmeans
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
sns.scatterplot(df["mean_over_speed_perc"],df["mean_dist_day"],hue=x["clusters"])
